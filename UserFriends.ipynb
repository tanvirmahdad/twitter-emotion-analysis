# %%
# %%javascript
# IPython.notebook.clear_all_output();

# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'RpJASzgH04rp1qlxZaP9bIOL9'
consumer_secret = '1h2xpOicibEwXH9Mo1A0eT1AQadutbUifiwiPD8CA8a9XhOHmq'
access_token = '1235642602952601600-RL7qqQl0GH9OsCwhTcviWs7urOQHvw'
access_secret = 'VvR3f932xIGnlyPCYTzCqxCzgjQpnJNr0If6oQKi8sZbS'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
# Get the User object
user = api.get_user('alsareini')
print(user.screen_name)
# Out:
# alsareini

# %%
print(user.followers_count)
# Out:
# 1509

# %%
print(user.friends_count)
# Out:
# 3361

# %%
# you can only see 20, need more pages...
for friend in user.friends():
   print(friend.screen_name)
# Out:
# tomhanks
# CaRodVee
# lesleeo66
# dad_darius
# GretaThunberg
# idiotIMpotus
# ljk222
# flanbites
# DarrelDrobnich
# AskCiti
# PositiveCharles
# JimmyFerris21
# METROEHS_
# ElzaghirZay
# IanMCohen
# RepAdamSchiff
# esglaude
# butwhatifitsall
# PDF_filler
# online420card

# %%
import time

ids = []

for page in tweepy.Cursor(api.friends_ids, screen_name="alsareini").pages():
    print(len(page), 'friends fetched')
    ids.extend(page)
    time.sleep(1) #RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]

len(ids)
# Out:
# 3361 friends fetched
# 3361

# %%
ids
# Out:
# [50374439,
#  25441295,
#  987469137403297792,
#  1044296977859538944,
#  1006419421244678144,
#  51910750,
#  346874444,
#  1017277256442339328,
#  500980657,
#  82151473,
#  758886359993987073,
#  1096520269466927104,
#  864468857230172162,
#  1204964954497060864,
#  353429316,
#  29501253,
#  180535644,
#  3163482711,
#  1342514822,
#  794325477083123712,
#  2256664812,
#  39837477,
#  37251642,
#  12,
#  822831865379901440,
#  939091,
#  26637348,
#  864464284063076353,
#  910492003359760384,
#  1053192497701122048,
#  26681152,
#  98471035,
#  2970279814,
#  167421802,
#  237230213,
#  912118622767730688,
#  787127154379218944,
#  18235902,
#  122474769,
#  21054720,
#  227780240,
#  31013444,
#  1082334352711790593,
#  1079769536730140672,
#  1080584229510172678,
#  85603854,
#  233842454,
#  75365104,
#  2255303941,
#  138203134,
#  10228272,
#  226222147,
#  43141060,
#  471677441,
#  4886050354,
#  125851115,
#  942038612387889152,
#  831603050817138688,
#  154311445,
# ...

# %% [markdown]
# Note: use this link to visit a user: https://twitter.com/intent/user?user_id={id}

# %%
# The End
